# %% [markdown]
# # Giga Chain
#  GigaСhain – это ответвление (fork) открытой библиотеки LangСhain на Python.
#
# ## Установка Giga Chain
# - !pip install gigachain-community - старая версия
#         https://github.com/ai-forever/gigachain
# - !pip install -U langchain-gigachat - новая версия
#     https://github.com/ai-forever/langchain-gigachat/tree/master/libs/gigachat
#
# https://github.com/ai-forever/gigachain/tree/master
#
# # Документация API
# https://developers.sber.ru/docs/ru/gigachat/api/overview
#
# https://github.com/ai-forever/gigachain/tree/master/hub/prompts - коллекция prompts
# https://courses.sberuniversity.ru/llm-gigachat/2/4/2 - Сбер университет, курс ЛЛМ

# %%
# !pip install gigachain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 1.2 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 25.0 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 36.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 38.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.1
#     Uninstalling numpy-2.1.1:
#       Successfully uninstalled numpy-2.1.1
# ...

# %%
# Иницилизация GigaChat
from langchain.chat_models import GigaChat
chat = GigaChat(credentials=<авторизационные данные>")

# %%
# Обращение к GigaChat
from langchain.chains import HumanMessage, SystemMessage
messages = [
    HumanMessage(content="Привет!"),
]
chat(messages).content
